# %%
x = (0, 1, 3)
a1, a2 = 500, 3
y = a1 .+ a2^(x

# %%
# Out:
# ParseError:
# # Error @ ]8;;file:///Users/vitorguerra/Projects/cocada/In[7]#2:1\In[7]:2:1]8;;\
# Ai = hcat(ones(length(3), A)
# ┌──────────
# C1 = A1 \ y
# Amodelo = (3.^(C1.*y)) + 500
# #──────────────────┘ ── Expected `)`
#
# Stacktrace:
#  [1] top-level scope
#    @ In[7]:2
