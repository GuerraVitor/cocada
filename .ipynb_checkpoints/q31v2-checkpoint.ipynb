# %%
#criando 30 valores de x aleatórios 
x = range(0, 1, length = 30)
#definindo os valores dos coeficientes
a1, a2, a3, a4, a5, a6 = 6.0, 5.0, 4.0, 3.0, 2.0, 1.0
#calculando os valores de y para o polinomio criado
y = a1*x .+ a2*x.^2 .+ a3*x.^3 .+ a4*x.^4 .+ a5*x.^5 .+ a6
# Out:
# 30-element Vector{Float64}:
#   1.0
#   1.2130102024026055
#   1.438957368989909
#   1.678992873583045
#   1.934393290205244
#   2.2065720940352977
#   2.4970913623610262
#   2.807673475532746
#   3.1402128179167335
#   3.496787478848698
#   3.8796709535872425
#   4.291343844267329
#   4.7345055608537585
#   ⋮
#   8.23642658926616
#   8.996430624144946
#   9.818799960938318
#  10.70872982298554
#  11.671751250990376
#  12.713742803974561
#  13.840942260231252
#  15.059958318278511
#  16.377782297812768
#  17.80179984066227
#  19.33980261174057
#  21.0

# %%
using Plots
scatter(x, y, legend = false)

# %%
#regressao com grau 0
A0 = ones(30, 1)
C0 = A0 \ y

E0 = A0*C0 .- y
somaE0 = sum(E0 .^2)
# Out:
# 1001.1157762708535

# %%
#regressao com grau 1
A1 = hcat(A0, x)
C1 = A1 \ y

E1 = A1*C1 .- y
somaE1 = sum(E1 .^ 2)
# Out:
# 77.8049215602568

# %%
#regressao com grau 2
A2 = hcat(A1, x.^2)
C2 = A2 \ y

E2 = A2*C2 - y
somaE2= sum(E2.^ 2)
# Out:
# 3.1974547252539036

# %%
#regressao com grau 3
A3 = hcat(A2, x.^3)
C3 = A3 \ y

E3 = A3*C3.- y
somaE3= sum(E3.^ 2)
# Out:
# 0.05544412745473369

# %%
#regressao com grau 4
A4 = hcat(A3, x.^4)
C4 = A4 \ y

E4 = A4*C4 .- y
somaE4 = sum(E4.^2)
# Out:
# 0.0002266800103528106

# %%
#regressao com grau 29
A29 = A4
for i in 4:29
    A29 = hcat(A29, x.^i)
end
C29 = A29 \ y

E29 = A29*C29 .- y
somaE29 = sum(E29.^2)
# Out:
# 4.531019824363187e-28

# %%
# regressao com grau 30
A30 = hcat(A29, x.^30)
C30 = A30 \ y

E30 = A30*C30 .- y
somaE30 = sum(E30.^2)
# Out:
# 1.7316729464765617e-28

# %%
plot!(x, C0[1] .* ones(length(x)))
plot!(x, C1[1] .+ C1[2].*x)
plot!(x, C2[1] .+ C2[2].*x .+ C2[3].*x.^2)
plot!(x, C3[1] .+ C3[2].*x .+ C3[3].*x.^2 .+ C3[4].*x.^3)

# %%
x_array = collect(x)

# Inicializar o polinômio de grau 30
C30plot = C30[1] .+ C30[2] .* x_array
for i in 3:31  
    C30plot .+= C30[i] .* x_array.^(i-1)
end

# Plotar o polinômio de grau 30
plot!(x_array, C30plot, label="Grau 30")

# %%
erro = [somaE0, somaE1, somaE2, somaE3, somaE4, somaE29, somaE30]
eixoX = ["E0", "E1", "E2", "E3", "E4", "E29", "E30"]
plot(eixoX, erro, yaxis=:log10, label="Erro", lw=2)
